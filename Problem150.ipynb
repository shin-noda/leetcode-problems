# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem150.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def evalRPN(self, tokens):
        """
        :type tokens: List[str]
        :rtype: int
        """

        # LIFO (Last-In First-Out)
        stack = []

        result = 0
        is_first_calc = True

        for t in tokens:
            if t == '+':
                n2 = stack.pop()
                n1 = stack.pop()

                stack.append(n1 + n2)

            elif t == '-':
                n2 = stack.pop()
                n1 = stack.pop()

                stack.append(n1 - n2)

            elif t == '*':
                n2 = stack.pop()
                n1 = stack.pop()

                stack.append(n1 * n2)

            elif t == '/':
                n2 = stack.pop()
                n1 = stack.pop()

                # We need this for Python 2
                stack.append(int(float(n1) / n2))

            else:
                stack.append(int(t))

        # There will be only one element in the stack at the end
        result = stack.pop()

        return result

# %%
solution = Solution()

# %%
tokens = ["2","1","+","3","*"]

print(solution.evalRPN(tokens))
# Out:
# 9

# %%
tokens = ["4","13","5","/","+"]

print(solution.evalRPN(tokens))
# Out:
# 6

# %%
tokens = ["10","6","9","3","+","-11","*","/","*","17","+","5","+"]

print(solution.evalRPN(tokens))
# Out:
# 22
