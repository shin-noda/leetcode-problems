# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def search(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: int
        """

        # Idea: since nums is originally in ascending order,
        # the peak of the value is somewhere in the middle (or edges).
        # We use binary search to find the target.

        left = 0
        right = len(nums) - 1
        while left <= right:
            mid = (left + right) // 2

            if nums[mid] == target:
                return mid

            elif nums[mid] < nums[right]:
                if nums[mid] < target <= nums[right]:
                    left = mid + 1

                else:
                    right = mid - 1

            elif nums[left] < nums[mid]:
                if nums[left] <= target < nums[mid]:
                    right = mid - 1

                else:
                    left = mid + 1

            elif nums[mid] == nums[left]:
                left = mid + 1

            elif nums[mid] == nums[right]:
                right = mid - 1

        return -1

# %%
solution = Solution()

# %%
nums = [4,5,6,7,0,1,2]
target = 0

print(solution.search(nums, target))
# Out:
# 4

# %%
nums = [4,5,6,7,0,1,2]
target = 3

print(solution.search(nums, target))
# Out:
# -1

# %%
nums = [1]
target = 0

print(solution.search(nums, target))
# Out:
# -1

# %%
nums = [1]
target = 1

print(solution.search(nums, target))
# Out:
# 0

# %%
nums = [4,5,6,7,0,1,2]
target = 5

print(solution.search(nums, target))
# Out:
# 1

# %%
nums = [4,5,6,7,0,1,2]
target = 8

print(solution.search(nums, target))
# Out:
# -1

# %%
nums = [4,5,6,7,0,1,2]
target = 2

print(solution.search(nums, target))
# Out:
# 6

# %%
nums = [0,1,2,4,5,6,7]
target = 2

print(solution.search(nums, target))
# Out:
# 2

# %%
nums = [0,1,2,4,5,6,7]
target = 0

print(solution.search(nums, target))
# Out:
# 0

# %%
nums = [0,1,2,4,5,6,7]
target = 7

print(solution.search(nums, target))
# Out:
# 6

# %%
nums = [0,1,2,4,5,6,7]
target = 5

print(solution.search(nums, target))
# Out:
# 4

# %%
nums = [8,0,1,2,4,5,6,7]
target = 8

print(solution.search(nums, target))
# Out:
# 0

# %%
nums = [8,0,1,2,4,5,6,7]
target = 0

print(solution.search(nums, target))
# Out:
# 1

# %%
nums = [3,1]
target = 1

print(solution.search(nums, target))
# Out:
# 1

# %%
nums = [3,1]
target = 3

print(solution.search(nums, target))
# Out:
# 0

# %%
nums = [1,3]
target = 1

print(solution.search(nums, target))
# Out:
# 0
