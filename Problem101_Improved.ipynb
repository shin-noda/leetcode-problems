# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem101_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for a binary tree node.
class TreeNode(object):
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
class Solution(object):
    def isSymmetric(self, root):
        """
        :type root: Optional[TreeNode]
        :rtype: bool
        """

        if not root:
            return True

        # Queue stores pairs that should be identical
        queue = [(root.left, root.right)]

        while queue:
            # This part is the same as the following
            # pair = queue.pop(0)
            # t1 = pair[0]
            # t2 = pair[1]

            t1, t2 = queue.pop(0)

            if not t1 and not t2:
                continue

            if not t1 or not t2 or t1.val != t2.val:
                return False

            # Key: Push the "mirrored" pairs together
            queue.append((t1.left, t2.right))
            queue.append((t1.right, t2.left))

        return True
