# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem61_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %%
class Solution(object):
    def rotateRight(self, head, k):
        """
        :type head: Optional[ListNode]
        :type k: int
        :rtype: Optional[ListNode]
        """

        # Check for edge cases
        if not head or not head.next or k == 0:
            return head

        # Find the length and the actual last node
        last = head
        length = 1
        while last.next:
            last = last.next
            length += 1

        # Connect the tail to the head to make it circular
        last.next = head

        # Find the new tail: (length - k % length - 1) steps from the start
        # and the new head is one node after that
        k = k % length
        steps_to_new_tail = length - k - 1

        new_tail = head
        for _ in range(steps_to_new_tail):
            new_tail = new_tail.next

        new_head = new_tail.next

        # 4. Break the circle
        new_tail.next = None

        return new_head
