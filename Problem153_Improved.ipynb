# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem153_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def findMin(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """

        # Idea: Is the middle element greater than the rightmost element?
        # If nums[mid] > nums[right] -> the minimum must be to the right of mid
        # Otherwise -> the minimum is either at mid or to its left

        left = 0
        right = len(nums) - 1

        while left < right:
            mid = (left + right) // 2

            # If mid is greater than the rightmost element,
            # the min must be in the right half.
            if nums[mid] > nums[right]:
                left = mid + 1

            # Otherwise, the pivot is in the left half (including mid).
            else:
                right = mid

        return nums[left]

# %%
solution = Solution()

# %%
nums = [3,4,5,1,2]

print(solution.findMin(nums))
# Out:
# 1

# %%
nums = [4,5,6,7,0,1,2]

print(solution.findMin(nums))
# Out:
# 0

# %%
nums = [11,13,15,17]

print(solution.findMin(nums))
# Out:
# 11

# %%
nums = [5, 10, 20, 30, 40, 50, 70, 90, 100]

print(solution.findMin(nums))
# Out:
# 5

# %%
nums = [80, 90, 100, 5, 10, 20, 30, 40, 50, 70]

print(solution.findMin(nums))
# Out:
# 5

# %%
nums = [30, 40, 50, 70, 90, 100, 5, 10, 20, ]

print(solution.findMin(nums))
# Out:
# 5

# %%
nums = [0,1,2]

print(solution.findMin(nums))
# Out:
# 0

# %%
nums = [0,1]

print(solution.findMin(nums))
# Out:
# 0

# %%
nums = [1,0]

print(solution.findMin(nums))
# Out:
# 0

# %%
nums = [1]

print(solution.findMin(nums))
# Out:
# 1
