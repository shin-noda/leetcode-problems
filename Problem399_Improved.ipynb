# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem399_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def calcEquation(self, equations, values, queries):
        """
        :type equations: List[List[str]]
        :type values: List[float]
        :type queries: List[List[str]]
        :rtype: List[float]
        """

        # Build the graph
        graph = {}
        for (a, b), val in zip(equations, values):
            if a not in graph:
                graph[a] = {}

            if b not in graph:
                graph[b] = {}

            # graph[a][b] is a map of maps.
            graph[a][b] = val
            graph[b][a] = 1.0 / val

        # Define DFS locally to share 'graph' scope easily
        def dfs(curr, target, visited):
            if curr not in graph or target not in graph:
                return -1.0

            if curr == target:
                return 1.0

            visited.add(curr)
            for neighbor, weight in graph[curr].items():
                if neighbor not in visited:
                    ret = dfs(neighbor, target, visited)

                    if ret != -1.0:
                        return weight * ret

            return -1.0

        # Process Queries
        results = []
        for start, end in queries:
            results.append(dfs(start, end, set()))

        return results

# %%
equations = [["a","b"],["b","c"]]
values = [2.0,3.0]
queries = [["a","c"],["b","a"],["a","e"],["a","a"],["x","x"]]

solution = Solution()
print(solution.calcEquation(equations, values, queries))
# Out:
# [6.0, 0.5, -1.0, 1.0, -1.0]

# %%
equations = [["a","b"],["b","c"],["bc","cd"]]
values = [1.5,2.5,5.0]
queries = [["a","c"],["c","b"],["bc","cd"],["cd","bc"]]

solution = Solution()
print(solution.calcEquation(equations, values, queries))
# Out:
# [3.75, 0.4, 5.0, 0.2]

# %%
equations = [["a","b"]]
values = [0.5]
queries = [["a","b"],["b","a"],["a","c"],["x","y"]]

solution = Solution()
print(solution.calcEquation(equations, values, queries))
# Out:
# [0.5, 2.0, -1.0, -1.0]
