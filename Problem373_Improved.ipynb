# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem373_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def kSmallestPairs(self, nums1, nums2, k):
        """
        :type nums1: List[int]
        :type nums2: List[int]
        :type k: int
        :rtype: List[List[int]]
        """

        # Initialize Min-Heap with (sum, i, j)
        # We only need to start with pairs (0, j) for j up to k
        heap = []

        for j in range(min(len(nums2), k)):
            # Store as (sum, nums1_index, nums2_index)
            self.heap_push(heap, (nums1[0] + nums2[j], 0, j))

        result = []

        # Extract the smallest k times
        while len(result) < k and heap:
            current_sum, i, j = self.heap_pop(heap)
            result.append([nums1[i], nums2[j]])

            # If there's a next element in nums1, push (i + 1, j)
            if i + 1 < len(nums1):
                next_sum = nums1[i + 1] + nums2[j]
                self.heap_push(heap, (next_sum, i + 1, j))

        return result



    def heap_push(self, heap, item):
        heap.append(item)
        idx = len(heap) - 1

        while idx > 0:
            parent = (idx - 1) // 2

            # Min-Heap: child < parent
            if heap[idx][0] < heap[parent][0]:
                heap[idx], heap[parent] = heap[parent], heap[idx]
                idx = parent

            else:
                break


    def heap_pop(self, heap):
        if len(heap) == 1:
            return heap.pop()

        root = heap[0]
        heap[0] = heap.pop()

        idx = 0
        while True:
            smallest = idx
            left = 2 * idx + 1
            right = 2 * idx + 2

            if left < len(heap) and heap[left][0] < heap[smallest][0]:
                smallest = left

            if right < len(heap) and heap[right][0] < heap[smallest][0]:
                smallest = right

            if smallest != idx:
                heap[idx], heap[smallest] = heap[smallest], heap[idx]
                idx = smallest

            else:
                break

        return root

# %%
solution = Solution()

# %%
nums1 = [1,7,11]
nums2 = [2,4,6]
k = 3

print(solution.kSmallestPairs(nums1, nums2, k))
# Out:
# [[1, 2], [1, 4], [1, 6]]

# %%
nums1 = [1,1,2]
nums2 = [1,2,3]
k = 2

print(solution.kSmallestPairs(nums1, nums2, k))
# Out:
# [[1, 1], [1, 1]]
