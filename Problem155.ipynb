# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem155.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class MinStack(object):

    def __init__(self):
        # Create an empty stack
        self.stack = []
        self.min_stack = []
        self.min_val = float('inf')


    def push(self, val):
        """
        :type val: int
        :rtype: None
        """
        # pushes the element val onto the stack
        # Update the min
        if val < self.min_val:
            self.min_val = val

        self.stack.append(val)

        # Push the min value
        self.min_stack.append(self.min_val)


    def pop(self):
        """
        :rtype: None
        """
        # removes the element on the top of the stack
        item = self.stack.pop()

        # pop the top min value
        self.min_stack.pop()

        # Update the min value
        if len(self.min_stack) <= 0:
            self.min_val = float('inf')

        else:
            self.min_val = self.min_stack[-1]


    def top(self):
        """
        :rtype: int
        """
        # gets the top element of the stack (no pop)
        return self.stack[-1]


    def getMin(self):
        """
        :rtype: int
        """
        # retrieves the minimum element in the stack.
        return self.min_val

# %%
# Your MinStack object will be instantiated and called as such:
minStack = MinStack()

# %%
print(minStack.push(-2))
print(minStack.push(0))
print(minStack.push(-3))
print(minStack.getMin())
print(minStack.pop())
print(minStack.top())
print(minStack.getMin())
# Out:
# None
# None
# None
# -3
# None
# 0
# -2
