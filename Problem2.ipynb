# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %%
class Solution(object):
    def addTwoNumbers(self, l1, l2):
        """
        :type l1: Optional[ListNode]
        :type l2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """

        n1 = 0
        n2 = 0
        n3 = 0

        i = 0
        node = l1
        while node:
            val = node.val
            node = node.next

            n1 = n1 + val * pow(10, i)
            i += 1

        i = 0
        node = l2
        while node:
            val = node.val
            node = node.next

            n2 = n2 + val * pow(10, i)
            i += 1

        n3 = n1 + n2

        s = str(n3)
        num = int(s[0])
        front_node = ListNode(num)

        for i in range(1, len(s)):
            num = int(s[i])
            node = ListNode(num)

            # Connect nodes
            node.next = front_node
            front_node = node

        return front_node

# %%
solution = Solution()

# %%
l1 = [2,4,3]
l2 = [5,6,4]

# Setup the nodes
node1 = ListNode(2)
node2 = ListNode(4)
node3 = ListNode(3)

node4 = ListNode(5)
node5 = ListNode(6)
node6 = ListNode(4)

# Connect them
node1.next = node2
node2.next = node3

node4.next = node5
node5.next = node6

print(solution.addTwoNumbers(node1, node4))
# Out:
# <__main__.ListNode object at 0x7cc77b71d940>

# %%
l1 = [0]
l2 = [0]

# Setup the nodes
node1 = ListNode(0)
node2 = ListNode(0)

print(solution.addTwoNumbers(node1, node2))
# Out:
# <__main__.ListNode object at 0x7cc77b71cfb0>

# %%
l1 = [9,9,9,9,9,9,9]
l2 = [9,9,9,9]

# Setup the nodes
node1 = ListNode(9)
node2 = ListNode(9)
node3 = ListNode(9)
node4 = ListNode(9)
node5 = ListNode(9)
node6 = ListNode(9)
node7 = ListNode(9)

node8 = ListNode(9)
node9 = ListNode(9)
node10 = ListNode(9)
node11 = ListNode(9)

# Connect them
node1.next = node2
node2.next = node3
node4.next = node5
node5.next = node6
node6.next = node7

node8.next = node9
node9.next = node10
node10.next = node11

print(solution.addTwoNumbers(node1, node8))
# Out:
# <__main__.ListNode object at 0x7cc77b71f620>
