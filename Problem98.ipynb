# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for a binary tree node.
class TreeNode(object):
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
class Solution(object):
    def isValidBST(self, root):
        """
        :type root: Optional[TreeNode]
        :rtype: bool
        """

        self.is_checking = True
        self.is_valid = True

        self.prev = float('-inf')

        self.helper(root)

        return self.is_valid

    def helper(self, root):
        # Base case
        if not root or not self.is_checking:
            return

        self.helper(root.left)

        # Invalid
        # It has "=" because it has to be less than the previous value.
        if self.prev >= root.val:
            self.is_valid = False
            self.is_checking = False
            return

        # Update the previous value
        self.prev = root.val

        self.helper(root.right)
