# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem58_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def lengthOfLastWord(self, s):
        """
        :type s: str
        :rtype: int
        """

        len_last_word = 0

        if len(s) == 0:
            return len_last_word

        index = len(s) - 1

        # Skip trailing spaces
        while index >= 0 and s[index] == ' ':
            index = index - 1

        # Count the last word
        while index >= 0 and s[index] != ' ':
            len_last_word = len_last_word + 1
            index = index - 1

        return len_last_word

# %%
solution = Solution()

# %%
s = "Hello World"

print(solution.lengthOfLastWord(s))
# Out:
# 5

# %%
s = "   fly me   to   the moon  "

print(solution.lengthOfLastWord(s))
# Out:
# 4

# %%
s = "luffy is still joyboy"

print(solution.lengthOfLastWord(s))
# Out:
# 6
