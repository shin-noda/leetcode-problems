# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem117.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for a Node.
class Node(object):
    def __init__(self, val=0, left=None, right=None, next=None):
        self.val = val
        self.left = left
        self.right = right
        self.next = next

# %%
class Solution(object):
    def connect(self, root):
        """
        :type root: Node
        :rtype: Node
        """

        # Check if the root is empty
        if not root:
            return None

        # We iterate each level as a slice and
        # connect from the left node to the right node to the rightmost node.

        queue = [root]
        while queue:
            n = len(queue)
            for i in range(n):
                node = queue.pop(0)

                if node.left:
                    queue.append(node.left)

                if node.right:
                    queue.append(node.right)

            new_queue = len(queue)

            # We connect a left node to a right node
            for i in range(new_queue - 1):
                queue[i].next = queue[i + 1]

        return root
