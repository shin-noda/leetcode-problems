# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem128_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def longestConsecutive(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """

        # Using a set for O(1) lookups
        # Sets are more memory efficient than hashmaps because
        # sets are basically hashmaps without values.
        num_set = set(nums)
        longest_streak = 0

        for num in num_set:
            # Only start counting if 'num' is the beginning of a sequence
            # We only go upward
            if num - 1 not in num_set:
                current_num = num
                current_streak = 1

                while current_num + 1 in num_set:
                    current_num += 1
                    current_streak += 1

                longest_streak = max(longest_streak, current_streak)

        return longest_streak

# %%
solution = Solution()

# %%
nums = [100,4,200,1,3,2]

print(solution.longestConsecutive(nums))
# Out:
# 4

# %%
nums = [0,3,7,2,5,8,4,6,0,1]

print(solution.longestConsecutive(nums))
# Out:
# 9

# %%
nums = [1,0,1,2]

print(solution.longestConsecutive(nums))
# Out:
# 3

# %%
nums = [0,1,2]

print(solution.longestConsecutive(nums))
# Out:
# 3

# %%
nums = []

print(solution.longestConsecutive(nums))
# Out:
# 0

# %%
nums = [0]

print(solution.longestConsecutive(nums))
# Out:
# 1

# %%
nums = [0,1,0,1]

print(solution.longestConsecutive(nums))
# Out:
# 2

# %%
nums = [0,2,4,6,8]

print(solution.longestConsecutive(nums))
# Out:
# 1
