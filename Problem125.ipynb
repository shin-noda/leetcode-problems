# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem125.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def isPalindrome(self, s):
        """
        :type s: str
        :rtype: bool
        """

        n = len(s)

        # Check if s is either 0 or 1 character.
        if n <= 1:
            return True

        # Use the two pointer method
        left = 0
        right = n - 1

        left_index = left
        right_index = right

        while left < right:
            if s[left].isalnum() and s[right].isalnum():
                # compare
                if s[left].lower() == s[right].lower():
                    # Move both pointers
                    left = left + 1
                    right = right - 1

                else:
                    # Not a palindrome
                    return False

            else:
                if not s[left].isalnum():
                    # Move the left pointer to the right
                    left = left + 1

                if not s[right].isalnum():
                    # Move the right pointer to the left
                    right = right - 1

        return True

# %%
solution = Solution()

# %%
s = "A man, a plan, a canal: Panama"

print(solution.isPalindrome(s))
# Out:
# True

# %%
s = "race a car"

print(solution.isPalindrome(s))
# Out:
# False

# %%
s = " "

print(solution.isPalindrome(s))
# Out:
# True

# %%
s = "A"

print(solution.isPalindrome(s))
# Out:
# True

# %%
s = "Hannah"

print(solution.isPalindrome(s))
# Out:
# True

# %%
s = "ababa"

print(solution.isPalindrome(s))
# Out:
# True

# %%
s = "abba"

print(solution.isPalindrome(s))
# Out:
# True

# %%
s = "abcba"

print(solution.isPalindrome(s))
# Out:
# True

# %%
s = "abb"

print(solution.isPalindrome(s))
# Out:
# False

# %%
s = "0P"

print(solution.isPalindrome(s))
# Out:
# False
