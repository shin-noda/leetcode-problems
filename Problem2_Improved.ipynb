# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem2_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %%
class Solution(object):
    def addTwoNumbers(self, l1, l2):
        """
        :type l1: Optional[ListNode]
        :type l2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """

        # Use the Carry-over method

        dummy = ListNode(0)
        curr = dummy
        carry = 0

        while l1 or l2 or carry:
            # Get values from nodes, or 0 if we've reached the end of a list
            v1 = 0
            v2 = 0

            if l1:
                v1 = l1.val

            if l2:
                v2 = l2.val

            # New digit math
            total = v1 + v2 + carry
            carry = total // 10
            new_digit = total % 10

            # Create the node and move forward
            curr.next = ListNode(new_digit)
            curr = curr.next

            # Move l1 and l2 pointers if they exist
            if l1:
                l1 = l1.next

            if l2:
                l2 = l2.next

        return dummy.next

# %%
solution = Solution()

# %%
l1 = [2,4,3]
l2 = [5,6,4]

# Setup the nodes
node1 = ListNode(2)
node2 = ListNode(4)
node3 = ListNode(3)

node4 = ListNode(5)
node5 = ListNode(6)
node6 = ListNode(4)

# Connect them
node1.next = node2
node2.next = node3

node4.next = node5
node5.next = node6

print(solution.addTwoNumbers(node1, node4))

# %%
l1 = [0]
l2 = [0]

# Setup the nodes
node1 = ListNode(0)
node2 = ListNode(0)

print(solution.addTwoNumbers(node1, node2))

# %%
l1 = [9,9,9,9,9,9,9]
l2 = [9,9,9,9]

# Setup the nodes
node1 = ListNode(9)
node2 = ListNode(9)
node3 = ListNode(9)
node4 = ListNode(9)
node5 = ListNode(9)
node6 = ListNode(9)
node7 = ListNode(9)

node8 = ListNode(9)
node9 = ListNode(9)
node10 = ListNode(9)
node11 = ListNode(9)

# Connect them
node1.next = node2
node2.next = node3
node4.next = node5
node5.next = node6
node6.next = node7

node8.next = node9
node9.next = node10
node10.next = node11

print(solution.addTwoNumbers(node1, node8))
