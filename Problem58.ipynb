# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem58.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def lengthOfLastWord(self, s):
        """
        :type s: str
        :rtype: int
        """

        len_last_word = 0

        if len(s) == 0:
            return len_last_word

        # Remove whitespace before and after the string
        stripped_string = s.strip()

        # Split the string by white space
        words = stripped_string.split()

        len_last_word = len(words[-1])

        return len_last_word

# %%
solution = Solution()

# %%
s = "Hello World"

print(solution.lengthOfLastWord(s))
# Out:
# 5

# %%
s = "   fly me   to   the moon  "

print(solution.lengthOfLastWord(s))
# Out:
# 4

# %%
s = "luffy is still joyboy"

print(solution.lengthOfLastWord(s))
# Out:
# 6
