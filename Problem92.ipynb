# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems/blob/main/Problem92.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %%
class Solution(object):
    def reverseBetween(self, head, left, right):
        """
        :type head: Optional[ListNode]
        :type left: int
        :type right: int
        :rtype: Optional[ListNode]
        """

        # We don't change anything
        if left == right:
            return head

        index_map = {}

        dummy = head

        before_start = None
        start = None
        end = None
        after_end = None

        index = 0
        prev = None

        is_reversing = False
        while head:
            if index == left - 2:
                before_start = head

            elif index == left - 1:
                end = head
                is_reversing = True
                prev = head

            elif index == right - 1:
                start = head

            elif index == right:
                after_end = head
                is_reversing = False

            if is_reversing:
                # Placeholder
                next = head.next

                # Update the next to reverse it
                head.next = prev

                prev = head
                head = next

            else:
                head = head.next

            index += 1

        if before_start:
            before_start.next = start

        else:
            dummy = start

        if end:
            end.next = after_end

        return dummy
